# %% [markdown]
# <a href="https://colab.research.google.com/github/0xbageltoes/dcm-colabs/blob/main/postbot_distilgpt2_emailgen_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <ceneter> Basic Demo: `postbot/distilgpt2-emailgen`
#
# > A basic demo for testing email generation. This notebook (by default) runs on CPU to illustrate compute viability on general machines.
#
# [Link to model card on huggingface](https://huggingface.co/postbot/distilgpt2-emailgen)
#
# ---

# %%
# !pip install -U -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 77.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 89.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 17.3 MB/s eta 0:00:00

# %%
# %%capture
#@markdown set up auto-formatting of cells in notebook

from IPython.display import HTML, display


def set_css():
    display(
        HTML(
            """
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  """
        )
    )
get_ipython().events.register("pre_run_cell", set_css)

# %%
from transformers import pipeline

model_tag = "postbot/distilgpt2-emailgen"
generator = pipeline(
              'text-generation', 
              model=model_tag, 
              do_sample=False,
              early_stopping=True,
            )
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/754 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/999k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/470 [00:00<?, ?B/s]

# %%
import pprint as pp

generation_args = {
    "min_length": 4,
    "max_length": 64,
    "length_penalty": 0.5,
    "no_repeat_ngram_size": 2,
    "do_sample": False,
    "num_beams": 4,
    "early_stopping": True,
    "repetition_penalty": 3.5,
}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# %%time

prompt = """
Hello, 

Following up on the bubblegum shipment."""

result = generator(
    prompt,
    **generation_args,
) # generate

pp.pprint(result[0]['generated_text'])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ('\n'
#  'Hello, \n'
#  '\n'
#  'Following up on the bubblegum shipment.\n'
#  'I will be sending you a copy of the <NUMBER>-page memo that I sent to your '
#  'office last week and it is now ready for delivery. Please let me know if you '
#  'have any questions or need further information. Thank you')
# CPU times: user 53 s, sys: 212 ms, total: 53.2 s
# Wall time: 53.6 s
